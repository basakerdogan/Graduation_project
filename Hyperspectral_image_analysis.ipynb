# %%
from scipy.io import loadmat
import pandas as pd


def read_HSI():
    X = loadmat('C:/Users/Basak/Desktop/indian_pines/Indian_pines_corrected.mat')['indian_pines_corrected']
    y = loadmat('C:/Users/Basak/Desktop/indian_pines/Indian_pines_gt.mat')['indian_pines_gt']
    print(f"X shape: {X.shape}\ny shape: {y.shape}")
    return X, y


X, y = read_HSI()
# Out:
# X shape: (145, 145, 200)
# y shape: (145, 145)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.axes_style('whitegrid')
fig = plt.figure(figsize = (12, 6))
#burada fig ile çoklu çizimi gerçekleştiriyoruz. figsize çerçevenin boyutunu verir

for i in range(1, 1+6):

    fig.add_subplot(2,3, i)
    q = np.random.randint(X.shape[2])
#read_hsi de okuduğumuz görüntüyü burada yeniden çiziyoruz.
#cmap_jet renklendirme stilimiz burada flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
#'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg',
#'gist_rainbow', 'rainbow', 'jet', 'turbo', 'nipy_spectral','gist_ncar'] kullanabiliriz.
    plt.imshow(X[:,:,q], cmap='jet')
    plt.axis('off')
    plt.title(f'band - {q}')
